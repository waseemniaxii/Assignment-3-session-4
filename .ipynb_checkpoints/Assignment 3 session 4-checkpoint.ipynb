# %% [markdown]
# # Assignment 3 Session 4

# %% [markdown]
# # ANS 1

# %%
nums = [1,2,3] # add 10 number 
nums.append(10)

# %%
nums
# Out:
# [1, 2, 3, 10]

# %% [markdown]
# # ANS 2

# %%
order = ["burger","fries","biryani","coke"] # add ice cream and remobe biyani 
print("orignal order",order)
order.append("ice cream")
print("after added ice cream",order)
order.remove("biryani")
print("final order",order)
# Out:
# orignal order ['burger', 'fries', 'biryani', 'coke']
# after added ice cream ['burger', 'fries', 'biryani', 'coke', 'ice cream']
# final order ['burger', 'fries', 'coke', 'ice cream']

# %% [markdown]
# # ANS 3

# %%
nums = [4,1,3,2] # assending order
nums.sort()
print("assending order",nums)
# Out:
# assending order [1, 2, 3, 4]

# %% [markdown]
# # ANS : 4

# %%
passengers = ["ali","zara","ahmad"] # add passenger 
print("orignal passengers",passengers)
passengers.insert(2,"sara")
print("passengers after sara enter",passengers)
passengers.remove("zara")
print("after zara got off",passengers)
passengers.reverse()
print("enterd firts",passengers)
# Out:
# orignal passengers ['ali', 'zara', 'ahmad']
# passengers after sara enter ['ali', 'zara', 'sara', 'ahmad']
# after zara got off ['ali', 'sara', 'ahmad']
# enterd firts ['ahmad', 'sara', 'ali']

# %% [markdown]
# # ANS : 5

# %%
text = "hello python world"
text_underscore= text.replace(" ", "_")
print("after replace =",text_underscore)
text_split=text.split()
print("after split =",text_split)
text_dash = text.replace(" ", "-")
print("after again replace =",text_dash)
# Out:
# after replace = hello_python_world
# after split = ['hello', 'python', 'world']
# after again replace = hello-python-world

# %% [markdown]
# # ANS :6

# %%
word = "javascrip"
len(word)>5
# Out:
# True

# %% [markdown]
# # ANS : 7

# %%
product_code = "SKU-12345-XYZ"
dash_position=product_code.index("-")
print("dash position =",dash_position)
dash_count=product_code.count("-")
print("count of dash =",dash_count)
product_prefix=product_code.removeprefix("SKU-")
print("after remove prefix =",product_prefix)
product_suffix=product_code.removesuffix("-XYZ")
print("after remove suffix =",product_suffix)
product_code = "SKU-12345-XYZ"
parts = product_code.split("-")
number = parts[1]
print(number)
# Out:
# dash position = 3
# count of dash = 2
# after remove prefix = 12345-XYZ
# after remove suffix = SKU-12345
# 12345

# %% [markdown]
# # ANS :8

# %%
cities = ["karachi","lahore","islamabad","quetta"]
cities.reverse()
print("reversed list =",cities)
# Out:
# reversed list = ['quetta', 'islamabad', 'lahore', 'karachi']

# %% [markdown]
# # Ans : 9

# %%
text = " Data Analysis with Python Is very powerfull " 
extra_spaces = text.strip()
print("after extra spaces remove =",extra_spaces)
title_case = text.title()
print("after title case =",title_case)
replace = text.replace("powerful", "important")
print("after replace =",replace)
position = text.find("Python")
print("postion of python word =",position)
# Out:
# after extra spaces remove = Data Analysis with Python Is very powerfull
# after title case =  Data Analysis With Python Is Very Powerfull
# after replace =  Data Analysis with Python Is very importantl
# postion of python word = 20

# %% [markdown]
# # ANS :10

# %%
data = [12,45,2,67,34,89,23,90] 
data.sort()
print("assending order =",data)
data.insert(3, 50)
print("after insert =",data)
data.reverse()
print("reverse and final result =",data)
# Out:
# assending order = [2, 12, 23, 34, 45, 67, 89, 90]
# after insert = [2, 12, 23, 50, 34, 45, 67, 89, 90]
# reverse and final result = [90, 89, 67, 45, 34, 50, 23, 12, 2]
